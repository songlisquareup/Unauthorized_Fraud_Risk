# %%
#Vega Setup
import logging
import pandas as pd
import numpy as np
from afterpay_gdp_interfaces import RedshiftHook

import datetime
import pytz
CST = pytz.timezone('Asia/Shanghai')

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 100)
logger = logging.getLogger()
logger.setLevel(logging.INFO)
vega = RedshiftHook(cluster='vega', okta_username='songli@squareup.com') # for vega connection
def vega_execute(query):
    import datetime
    """
        vega execute SQL wrapper to commit everytime
    """
    t_start = datetime.datetime.now()
    with vega.get_conn() as vega_conn:
        with vega_conn.cursor() as cur:
            cur.execute(query)
        vega_conn.commit()
        t_end = datetime.datetime.now()
        logging.info("Vega Query Finished. Time used: {}".format(str(t_end - t_start)))
        # vega_conn.close()
pd.set_option('display.max_columns', None)  # or 1000
pd.set_option('display.max_rows', None)  # or 1000
pd.set_option('display.max_colwidth', None)  # or 199

# %%
import tensorflow_decision_forests as tfdf
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import math

# %% [markdown]
# # Gen Table

# %%
table_name='xxxx'

# %%
q=f"""
create table sandbox_analytics_au.{table_name} as (
with 
et as 
(select 
    *
    ,zticket_created_at::date as report_date
    
    FROM sandbox_analytics_au.ys_ato_ticket_tracking
    where final_tag in ('4-ato', '5-high-prob-ato'))
,cb_et as 
(select 
* from 
(
select *, ROW_NUMBER() over (partition by order_id order by chargeback_received_date) rn
from green.cur_p_f_chargeback where status = 'NotificationOfFraud' 
) where rn = 1
) 
,f as (
select order_token, id as order_id 
from green.f_order)
,base as (
select * from
sandbox_analytics_au.feature_base_sl a
where

  1=1
   and a.rule_ids='["Approved"]'
   and a.merchant_id in ('86841', '100114786') --US, AU
)
select 
a.*
,t.chargeback_created_date_first::date as cb_report_date
,issue_datetime::date as gwr_report_date
,et.report_date as et_report_date
,cb_et.chargeback_received_date::date as cb_et_report_date

from base a

left join curated_fraud_risk_green.yy_combine_cb_table_order_temp t
on a.order_token = t.order_token
and t.cb_type not like '%Merchandise%'
and t.order_source = 'Online'
 
left join sandbox_analytics_au.ys_cb_tagging_order_lvl b
on t.order_id = b.order_id
left join sandbox_analytics_au.mw_ato_goodwill_refund_3 r
on a.order_token = r.order_token
and r.order_dispute_reason = 'UNAUTHORIZED_TRANSACTION'

left join 
    f
on a.order_token=f.order_token
left join
et 
on f.order_id=et.order_id
left join 
cb_et
on f.order_id=cb_et.order_id

)

;"""

# %%
# %%time
print(datetime.datetime.now(CST))
vega_execute(q)
# Out:
# 2023-04-13 11:26:53.878791+08:00
# INFO:root:Vega Query Finished. Time used: 0:04:02.624344
# CPU times: user 5.32 ms, sys: 5.12 ms, total: 10.4 ms
# Wall time: 4min 2s

# %% [markdown]
# # End

# %%
q=f"""select * from sandbox_analytics_au.{table_name}"""

# %%
# %%time
print(datetime.datetime.now(CST))
case=vega.get_pandas_df(q)

case[['cb_report_date', 'gwr_report_date', 'et_report_date','cb_et_report_date']]=case[['cb_report_date', 'gwr_report_date', 'et_report_date','cb_et_report_date']].apply(pd.to_datetime)

case['min_report_date']=case[['cb_report_date', 'gwr_report_date', 'et_report_date','cb_et_report_date']].min(axis=1)

case['real_min_report_date']=case[['cb_report_date', 'gwr_report_date', 'cb_et_report_date']].min(axis=1)

case['order_date']=pd.to_datetime(case['checkout_time']).dt.date
import datetime
case['order_week']=case['order_date']-case['order_date'].apply(lambda x: datetime.timedelta(pd.to_datetime(x).weekday()))   

import math
case['tfa_days']=(pd.to_datetime(case['checkout_time'])-pd.to_datetime((pd.to_numeric(case['c_latest_login_2fa_success_timestamp']))\
                                                                    .apply(lambda x:datetime.datetime.fromtimestamp(0 if math.isnan(x) else x)))).dt.days
case['pw_days']=(pd.to_datetime(case['checkout_time'])-pd.to_datetime((pd.to_numeric(case['c_latest_pwd_reset_success_timestamp']))\
                                                                   .apply(lambda x:datetime.datetime.fromtimestamp(0 if math.isnan(x) else x)))).dt.days
case['otp_days']=(pd.to_datetime(case['checkout_time'])-pd.to_datetime((pd.to_numeric(case['sp_c_latest_otp_login_success_timestamp']/1000))\
                                                                   .apply(lambda x:datetime.datetime.fromtimestamp(0 if math.isnan(x) else x)))).dt.days

#case.dtypes
case.order_date=pd.to_datetime(case.order_date)

case['loss_ind']=(~case['min_report_date'].isna() )
case['loss_ind_real']=(~case['real_min_report_date'].isna())
case.loc[~(case['loss_ind_real']) & (case['loss_ind']),'loss_ind']=0.5

case['pw_tfa_days']=case[['pw_days','tfa_days','otp_days']].apply(lambda x: x.min(),axis=1)
case['pw_tfa_days_group']=pd.cut(case['pw_tfa_days'], [0,7,14,30,60,np.inf], include_lowest=True)

#device age
case['device_age_group']=pd.cut(case['device_age_in_days'], [0,1,7,30, 60, np.inf], include_lowest=True)

case['recipient_domain']=case['in_flight_order_recipient_email'].apply(lambda x: x.split('@')[-1])

case['email_mismatch']=(case['in_flight_order_consumer_email'].str.lower()!=case['consumer_email'].str.lower()).fillna(True)

case['tenure']=pd.cut(case['days_since_first_order_date'], [0,42, np.inf], include_lowest=True)

# %%
table=case.query("""checkout_time >'2023-01-01' and  rule_ids=='["Approved"]' """)\
    .pivot_table(values='in_flight_order_amount',index=['par_region','device_age_group'], columns='loss_ind', aggfunc='count', dropna=False, margins=True)
table['rate']=(table[1]/table['All']).apply('{:.2%}'.format)

table

# days since first order date

table=case.query("""checkout_time >'2023-01-01' and  rule_ids=='["Approved"]' """)\
    .pivot_table(values='in_flight_order_amount',index=['par_region','tenure'], columns='loss_ind', aggfunc='count', dropna=False, margins=True)
table['rate']=(table[1]/table['All']).apply('{:.2%}'.format)

table

# check 2fa group fraud rate distribution

table=case.query("""checkout_time >'2023-01-01' and  rule_ids=='["Approved"]' """)\
    .pivot_table(values='in_flight_order_amount',index=['par_region','pw_tfa_days_group'], columns='loss_ind', aggfunc='count', dropna=False, margins=True)

table['rate']=(table[1]/table['All']).apply('{:.2%}'.format)

table

# Email mismatch

table=case.query("""checkout_time >'2023-01-01' and  rule_ids=='["Approved"]' """)\
    .pivot_table(values='in_flight_order_amount',index=['par_region','email_mismatch'], columns='loss_ind', aggfunc='count', dropna=False, margins=True)

table['rate']=(table[1]/table['All']).apply('{:.2%}'.format)

table
# Out:
# loss_ind                       False    0.5    True      All   rate
# par_region email_mismatch
# AU         False            532839.0    NaN   169.0   533008  0.03%
#            True              81379.0    NaN    80.0    81459  0.10%
# US         False            484618.0   99.0   552.0   485269  0.11%
#            True              77201.0   58.0   437.0    77696  0.56%
# All                        1176037.0  157.0  1238.0  1177432  0.11%

# %% [markdown]
# # Aggregate

# %% [markdown]
# ## Run date version

# %%
case=case.query("""checkout_time >'2023-01-01' and  rule_ids=='["Approved"]' """)

# %%
case_run=case.query("""checkout_time >'2023-01-01' and  rule_ids=='["Approved"]' """)\
    [['par_region','tenure','email_mismatch','pw_tfa_days_group','device_age_group','order_date','min_report_date','real_min_report_date','loss_ind','rule_ids']].copy()

# %%
#bad.dtypes
case_run['min_report_date']=pd.to_datetime(case_run['min_report_date'])
case_run['order_date']=pd.to_datetime(case_run['order_date'])
case_run['real_min_report_date']=pd.to_datetime(case_run['real_min_report_date'])

# %%
case_run['tenure']=case_run['tenure'].apply(lambda x:str(x))
case_run['pw_tfa_days_group']=case_run['pw_tfa_days_group'].apply(lambda x:str(x))
case_run['device_age_group']=case_run['device_age_group'].apply(lambda x:str(x))

# %%
case_run.head()
# Out:
#   par_region       tenure  email_mismatch pw_tfa_days_group device_age_group  \
# 0         AU  (42.0, inf]           False       (60.0, inf]      (60.0, inf]
# 1         AU  (42.0, inf]           False      (30.0, 60.0]      (60.0, inf]
# 2         AU  (42.0, inf]           False       (7.0, 14.0]      (60.0, inf]
# 3         AU  (42.0, inf]           False       (60.0, inf]    (-0.001, 1.0]
# 4         AU  (42.0, inf]           False      (30.0, 60.0]      (60.0, inf]
#
#   order_date min_report_date real_min_report_date loss_ind      rule_ids
# 0 2023-04-07             NaT                  NaT    False  ["Approved"]
# 1 2023-04-09             NaT                  NaT    False  ["Approved"]
# 2 2023-04-10             NaT                  NaT    False  ["Approved"]
# 3 2023-04-11             NaT                  NaT    False  ["Approved"]
# 4 2023-03-30             NaT                  NaT    False  ["Approved"]

# %%
run_date_list=pd.DataFrame(pd.date_range(case_run.order_date.min()+datetime.timedelta(days=7),case_run.order_date.max()+datetime.timedelta(days=1),freq='d'), columns=['run_date'])

#run_date_list.dtypes
run_date_list['run_date']=pd.to_datetime(run_date_list['run_date'])

run_date_list['run_date_1']=(pd.to_datetime(run_date_list['run_date'])-datetime.timedelta(days=1))
run_date_list['run_date_7']=(pd.to_datetime(run_date_list['run_date'])-datetime.timedelta(days=7))

# %%
# %%time
import pandasql as ps

sqlcode = '''
select
case_run.*
,a.run_date
,case when real_min_report_date<run_date then 1  
when min_report_date<run_date then 0.5
else 0 end as loss_ind_run
from run_date_list a
left join case_run 
on date(case_run.order_date) between run_date_7 and run_date_1

'''

newdf = ps.sqldf(sqlcode,locals())
# Out:
# CPU times: user 52 s, sys: 2.51 s, total: 54.5 s
# Wall time: 54.6 s

# %%
newdf.head()
# Out:
#   par_region       tenure  email_mismatch pw_tfa_days_group device_age_group  \
# 0         AU  (42.0, inf]               0       (60.0, inf]      (60.0, inf]
# 1         AU  (42.0, inf]               0      (14.0, 30.0]      (60.0, inf]
# 2         AU  (42.0, inf]               1       (7.0, 14.0]    (-0.001, 1.0]
# 3         US  (42.0, inf]               0     (-0.001, 7.0]      (60.0, inf]
# 4         US  (42.0, inf]               0       (7.0, 14.0]      (60.0, inf]
#
#                    order_date min_report_date real_min_report_date loss_ind  \
# 0  2023-02-14 00:00:00.000000            None                 None        0
# 1  2023-02-15 00:00:00.000000            None                 None        0
# 2  2023-02-17 00:00:00.000000            None                 None        0
# 3  2023-02-12 00:00:00.000000            None                 None        0
# 4  2023-02-12 00:00:00.000000            None                 None        0
#
#        rule_ids                    run_date  loss_ind_run
# 0  ["Approved"]  2023-02-18 00:00:00.000000           0.0
# 1  ["Approved"]  2023-02-18 00:00:00.000000           0.0
# 2  ["Approved"]  2023-02-18 00:00:00.000000           0.0
# 3  ["Approved"]  2023-02-18 00:00:00.000000           0.0
# 4  ["Approved"]  2023-02-18 00:00:00.000000           0.0

# %%
newdf.shape
# Out:
# (6388343, 12)

# %%
newdf.loss_ind.value_counts()
# Out:
# 0      6380567
# 1         6942
# 0.5        834
# Name: loss_ind, dtype: int64

# %%
newdf.run_date=pd.to_datetime(newdf.run_date).dt.date

# %%
#report date
bad=newdf.query("""order_date >'2023-01-01' and  rule_ids=='["Approved"]' """)\
    .pivot_table(values='loss_ind_run',index=['par_region','tenure','email_mismatch','pw_tfa_days_group','device_age_group']
                 , columns=['run_date'], aggfunc='sum',dropna=False)

total=newdf.query("""order_date >'2023-01-01' and  rule_ids=='["Approved"]' """)\
    .pivot_table(values='loss_ind_run',index=['par_region','tenure','email_mismatch','pw_tfa_days_group','device_age_group']
                 , columns=['run_date'], aggfunc='count',dropna=False)

bad_rate=(bad/total)
bad_rate_rolling=bad_rate.rolling(7,axis=1).mean()

# %%
#trigger logic
report=bad_rate[(bad_rate>0.005) & ((bad_rate>3*bad_rate_rolling) & (bad>=3) | (bad>=5))].dropna(how='all').dropna(how='all',axis=1)#.applymap('{:.2%}'.format)

# %%
report
# Out:
# run_date                                                                  2023-02-21  \
# par_region tenure      email_mismatch pw_tfa_days_group device_age_group
# AU         (42.0, inf] 0              (-0.001, 7.0]     (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN
# US         (42.0, inf] 0              (-0.001, 7.0]     (-0.001, 1.0]            NaN
#                                                         (1.0, 7.0]          0.019934
#                                                         (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                        1              (-0.001, 7.0]     (1.0, 7.0]               NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN
#
# run_date                                                                  2023-02-26  \
# par_region tenure      email_mismatch pw_tfa_days_group device_age_group
# AU         (42.0, inf] 0              (-0.001, 7.0]     (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN
# US         (42.0, inf] 0              (-0.001, 7.0]     (-0.001, 1.0]       0.007975
#                                                         (1.0, 7.0]               NaN
#                                                         (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                        1              (-0.001, 7.0]     (1.0, 7.0]          0.125000
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN
#
# run_date                                                                  2023-02-27  \
# par_region tenure      email_mismatch pw_tfa_days_group device_age_group
# AU         (42.0, inf] 0              (-0.001, 7.0]     (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN
# US         (42.0, inf] 0              (-0.001, 7.0]     (-0.001, 1.0]            NaN
#                                                         (1.0, 7.0]               NaN
#                                                         (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                        1              (-0.001, 7.0]     (1.0, 7.0]          0.155556
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN
#
# run_date                                                                  2023-02-28  \
# par_region tenure      email_mismatch pw_tfa_days_group device_age_group
# AU         (42.0, inf] 0              (-0.001, 7.0]     (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN
# US         (42.0, inf] 0              (-0.001, 7.0]     (-0.001, 1.0]            NaN
#                                                         (1.0, 7.0]               NaN
#                                                         (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                        1              (-0.001, 7.0]     (1.0, 7.0]              0.16
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN
#
# run_date                                                                  2023-03-01  \
# par_region tenure      email_mismatch pw_tfa_days_group device_age_group
# AU         (42.0, inf] 0              (-0.001, 7.0]     (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN
# US         (42.0, inf] 0              (-0.001, 7.0]     (-0.001, 1.0]            NaN
#                                                         (1.0, 7.0]               NaN
#                                                         (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                        1              (-0.001, 7.0]     (1.0, 7.0]          0.117021
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN
#
# run_date                                                                  2023-03-03  \
# par_region tenure      email_mismatch pw_tfa_days_group device_age_group
# AU         (42.0, inf] 0              (-0.001, 7.0]     (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN
# US         (42.0, inf] 0              (-0.001, 7.0]     (-0.001, 1.0]            NaN
#                                                         (1.0, 7.0]               NaN
#                                                         (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                        1              (-0.001, 7.0]     (1.0, 7.0]               NaN
#                                                         (7.0, 30.0]         0.053571
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN
#
# run_date                                                                  2023-03-04  \
# par_region tenure      email_mismatch pw_tfa_days_group device_age_group
# AU         (42.0, inf] 0              (-0.001, 7.0]     (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN
# US         (42.0, inf] 0              (-0.001, 7.0]     (-0.001, 1.0]            NaN
#                                                         (1.0, 7.0]               NaN
#                                                         (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                        1              (-0.001, 7.0]     (1.0, 7.0]          0.109375
#                                                         (7.0, 30.0]         0.109091
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN
#
# run_date                                                                  2023-03-05  \
# par_region tenure      email_mismatch pw_tfa_days_group device_age_group
# AU         (42.0, inf] 0              (-0.001, 7.0]     (30.0, 60.0]        0.010178
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN
# US         (42.0, inf] 0              (-0.001, 7.0]     (-0.001, 1.0]            NaN
#                                                         (1.0, 7.0]               NaN
#                                                         (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                        1              (-0.001, 7.0]     (1.0, 7.0]          0.134615
#                                                         (7.0, 30.0]         0.088235
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN
#
# run_date                                                                  2023-03-06  \
# par_region tenure      email_mismatch pw_tfa_days_group device_age_group
# AU         (42.0, inf] 0              (-0.001, 7.0]     (30.0, 60.0]        0.010471
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN
# US         (42.0, inf] 0              (-0.001, 7.0]     (-0.001, 1.0]            NaN
#                                                         (1.0, 7.0]               NaN
#                                                         (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                        1              (-0.001, 7.0]     (1.0, 7.0]          0.087838
#                                                         (7.0, 30.0]         0.086957
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN
#
# run_date                                                                  2023-03-07  \
# par_region tenure      email_mismatch pw_tfa_days_group device_age_group
# AU         (42.0, inf] 0              (-0.001, 7.0]     (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN
# US         (42.0, inf] 0              (-0.001, 7.0]     (-0.001, 1.0]            NaN
#                                                         (1.0, 7.0]               NaN
#                                                         (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                        1              (-0.001, 7.0]     (1.0, 7.0]               NaN
#                                                         (7.0, 30.0]         0.089552
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN
#
# run_date                                                                  2023-03-08  \
# par_region tenure      email_mismatch pw_tfa_days_group device_age_group
# AU         (42.0, inf] 0              (-0.001, 7.0]     (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN
# US         (42.0, inf] 0              (-0.001, 7.0]     (-0.001, 1.0]            NaN
#                                                         (1.0, 7.0]               NaN
#                                                         (30.0, 60.0]        0.009009
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                        1              (-0.001, 7.0]     (1.0, 7.0]               NaN
#                                                         (7.0, 30.0]         0.082192
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN
#
# run_date                                                                  2023-03-09  \
# par_region tenure      email_mismatch pw_tfa_days_group device_age_group
# AU         (42.0, inf] 0              (-0.001, 7.0]     (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN
# US         (42.0, inf] 0              (-0.001, 7.0]     (-0.001, 1.0]            NaN
#                                                         (1.0, 7.0]               NaN
#                                                         (30.0, 60.0]        0.009772
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                        1              (-0.001, 7.0]     (1.0, 7.0]          0.062500
#                                                         (7.0, 30.0]         0.075758
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN
#
# run_date                                                                  2023-03-10  \
# par_region tenure      email_mismatch pw_tfa_days_group device_age_group
# AU         (42.0, inf] 0              (-0.001, 7.0]     (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN
# US         (42.0, inf] 0              (-0.001, 7.0]     (-0.001, 1.0]            NaN
#                                                         (1.0, 7.0]               NaN
#                                                         (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                        1              (-0.001, 7.0]     (1.0, 7.0]               NaN
#                                                         (7.0, 30.0]         0.084746
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN
#
# run_date                                                                  2023-03-11  \
# par_region tenure      email_mismatch pw_tfa_days_group device_age_group
# AU         (42.0, inf] 0              (-0.001, 7.0]     (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN
# US         (42.0, inf] 0              (-0.001, 7.0]     (-0.001, 1.0]            NaN
#                                                         (1.0, 7.0]          0.023885
#                                                         (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                        1              (-0.001, 7.0]     (1.0, 7.0]               NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN
#
# run_date                                                                  2023-03-12  \
# par_region tenure      email_mismatch pw_tfa_days_group device_age_group
# AU         (42.0, inf] 0              (-0.001, 7.0]     (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN
# US         (42.0, inf] 0              (-0.001, 7.0]     (-0.001, 1.0]            NaN
#                                                         (1.0, 7.0]          0.027508
#                                                         (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                        1              (-0.001, 7.0]     (1.0, 7.0]          0.083333
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]         0.052239
#
# run_date                                                                  2023-03-13  \
# par_region tenure      email_mismatch pw_tfa_days_group device_age_group
# AU         (42.0, inf] 0              (-0.001, 7.0]     (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN
# US         (42.0, inf] 0              (-0.001, 7.0]     (-0.001, 1.0]            NaN
#                                                         (1.0, 7.0]          0.023438
#                                                         (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                        1              (-0.001, 7.0]     (1.0, 7.0]          0.136364
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]         0.097902
#
# run_date                                                                  2023-03-14  \
# par_region tenure      email_mismatch pw_tfa_days_group device_age_group
# AU         (42.0, inf] 0              (-0.001, 7.0]     (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN
# US         (42.0, inf] 0              (-0.001, 7.0]     (-0.001, 1.0]            NaN
#                                                         (1.0, 7.0]          0.024351
#                                                         (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                        1              (-0.001, 7.0]     (1.0, 7.0]          0.122642
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]         0.071429
#
# run_date                                                                  2023-03-15  \
# par_region tenure      email_mismatch pw_tfa_days_group device_age_group
# AU         (42.0, inf] 0              (-0.001, 7.0]     (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN
# US         (42.0, inf] 0              (-0.001, 7.0]     (-0.001, 1.0]            NaN
#                                                         (1.0, 7.0]               NaN
#                                                         (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                        1              (-0.001, 7.0]     (1.0, 7.0]          0.173077
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]         0.071429
#
# run_date                                                                  2023-03-16  \
# par_region tenure      email_mismatch pw_tfa_days_group device_age_group
# AU         (42.0, inf] 0              (-0.001, 7.0]     (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN
# US         (42.0, inf] 0              (-0.001, 7.0]     (-0.001, 1.0]            NaN
#                                                         (1.0, 7.0]               NaN
#                                                         (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                        1              (-0.001, 7.0]     (1.0, 7.0]          0.160377
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]         0.120000
#
# run_date                                                                  2023-03-17  \
# par_region tenure      email_mismatch pw_tfa_days_group device_age_group
# AU         (42.0, inf] 0              (-0.001, 7.0]     (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN
# US         (42.0, inf] 0              (-0.001, 7.0]     (-0.001, 1.0]            NaN
#                                                         (1.0, 7.0]               NaN
#                                                         (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]         0.011858
#                                       (7.0, 14.0]       (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                        1              (-0.001, 7.0]     (1.0, 7.0]          0.197917
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]         0.133028
#
# run_date                                                                  2023-03-18  \
# par_region tenure      email_mismatch pw_tfa_days_group device_age_group
# AU         (42.0, inf] 0              (-0.001, 7.0]     (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN
# US         (42.0, inf] 0              (-0.001, 7.0]     (-0.001, 1.0]            NaN
#                                                         (1.0, 7.0]               NaN
#                                                         (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]         0.018868
#                                       (14.0, 30.0]      (7.0, 30.0]         0.012793
#                                       (7.0, 14.0]       (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                        1              (-0.001, 7.0]     (1.0, 7.0]          0.260417
#                                                         (7.0, 30.0]         0.085106
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]         0.088542
#
# run_date                                                                  2023-03-19  \
# par_region tenure      email_mismatch pw_tfa_days_group device_age_group
# AU         (42.0, inf] 0              (-0.001, 7.0]     (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN
# US         (42.0, inf] 0              (-0.001, 7.0]     (-0.001, 1.0]            NaN
#                                                         (1.0, 7.0]               NaN
#                                                         (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]         0.018519
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]         0.026393
#                        1              (-0.001, 7.0]     (1.0, 7.0]          0.404255
#                                                         (7.0, 30.0]         0.070175
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]         0.087912
#
# run_date                                                                  2023-03-20  \
# par_region tenure      email_mismatch pw_tfa_days_group device_age_group
# AU         (42.0, inf] 0              (-0.001, 7.0]     (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]         0.008086
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN
# US         (42.0, inf] 0              (-0.001, 7.0]     (-0.001, 1.0]            NaN
#                                                         (1.0, 7.0]               NaN
#                                                         (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]         0.025070
#                        1              (-0.001, 7.0]     (1.0, 7.0]          0.291667
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]         0.035714
#                                       (7.0, 14.0]       (7.0, 30.0]         0.117857
#
# run_date                                                                  2023-03-21  \
# par_region tenure      email_mismatch pw_tfa_days_group device_age_group
# AU         (42.0, inf] 0              (-0.001, 7.0]     (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]         0.008065
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN
# US         (42.0, inf] 0              (-0.001, 7.0]     (-0.001, 1.0]            NaN
#                                                         (1.0, 7.0]               NaN
#                                                         (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]         0.037815
#                        1              (-0.001, 7.0]     (1.0, 7.0]          0.164062
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]         0.114815
#
# run_date                                                                  2023-03-22  \
# par_region tenure      email_mismatch pw_tfa_days_group device_age_group
# AU         (42.0, inf] 0              (-0.001, 7.0]     (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]         0.009950
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN
# US         (42.0, inf] 0              (-0.001, 7.0]     (-0.001, 1.0]            NaN
#                                                         (1.0, 7.0]               NaN
#                                                         (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (30.0, 60.0]        0.022556
#                                                         (7.0, 30.0]         0.043103
#                        1              (-0.001, 7.0]     (1.0, 7.0]          0.079710
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]         0.081081
#
# run_date                                                                  2023-03-23  \
# par_region tenure      email_mismatch pw_tfa_days_group device_age_group
# AU         (42.0, inf] 0              (-0.001, 7.0]     (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]         0.009662
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN
# US         (42.0, inf] 0              (-0.001, 7.0]     (-0.001, 1.0]            NaN
#                                                         (1.0, 7.0]          0.023109
#                                                         (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (30.0, 60.0]        0.020000
#                                                         (7.0, 30.0]         0.014045
#                        1              (-0.001, 7.0]     (1.0, 7.0]          0.117647
#                                                         (7.0, 30.0]         0.110390
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]         0.081818
#
# run_date                                                                  2023-03-24  \
# par_region tenure      email_mismatch pw_tfa_days_group device_age_group
# AU         (42.0, inf] 0              (-0.001, 7.0]     (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN
# US         (42.0, inf] 0              (-0.001, 7.0]     (-0.001, 1.0]            NaN
#                                                         (1.0, 7.0]               NaN
#                                                         (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                        1              (-0.001, 7.0]     (1.0, 7.0]          0.168421
#                                                         (7.0, 30.0]         0.100000
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]         0.125000
#
# run_date                                                                  2023-03-25  \
# par_region tenure      email_mismatch pw_tfa_days_group device_age_group
# AU         (42.0, inf] 0              (-0.001, 7.0]     (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]         0.007160
# US         (42.0, inf] 0              (-0.001, 7.0]     (-0.001, 1.0]            NaN
#                                                         (1.0, 7.0]               NaN
#                                                         (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                        1              (-0.001, 7.0]     (1.0, 7.0]          0.207447
#                                                         (7.0, 30.0]         0.144737
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]         0.128099
#
# run_date                                                                  2023-03-26  \
# par_region tenure      email_mismatch pw_tfa_days_group device_age_group
# AU         (42.0, inf] 0              (-0.001, 7.0]     (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]         0.007335
# US         (42.0, inf] 0              (-0.001, 7.0]     (-0.001, 1.0]            NaN
#                                                         (1.0, 7.0]          0.029052
#                                                         (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]         0.019656
#                        1              (-0.001, 7.0]     (1.0, 7.0]          0.274194
#                                                         (7.0, 30.0]         0.085714
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN
#
# run_date                                                                  2023-03-27  \
# par_region tenure      email_mismatch pw_tfa_days_group device_age_group
# AU         (42.0, inf] 0              (-0.001, 7.0]     (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN
# US         (42.0, inf] 0              (-0.001, 7.0]     (-0.001, 1.0]       0.006878
#                                                         (1.0, 7.0]          0.040845
#                                                         (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                        1              (-0.001, 7.0]     (1.0, 7.0]          0.154930
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN
#
# run_date                                                                  2023-03-28  \
# par_region tenure      email_mismatch pw_tfa_days_group device_age_group
# AU         (42.0, inf] 0              (-0.001, 7.0]     (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN
# US         (42.0, inf] 0              (-0.001, 7.0]     (-0.001, 1.0]            NaN
#                                                         (1.0, 7.0]          0.024781
#                                                         (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                        1              (-0.001, 7.0]     (1.0, 7.0]          0.192982
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]         0.041667
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN
#
# run_date                                                                  2023-03-29  \
# par_region tenure      email_mismatch pw_tfa_days_group device_age_group
# AU         (42.0, inf] 0              (-0.001, 7.0]     (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN
# US         (42.0, inf] 0              (-0.001, 7.0]     (-0.001, 1.0]            NaN
#                                                         (1.0, 7.0]               NaN
#                                                         (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                        1              (-0.001, 7.0]     (1.0, 7.0]               NaN
#                                                         (7.0, 30.0]         0.142857
#                                       (14.0, 30.0]      (7.0, 30.0]         0.041667
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN
#
# run_date                                                                  2023-04-07  \
# par_region tenure      email_mismatch pw_tfa_days_group device_age_group
# AU         (42.0, inf] 0              (-0.001, 7.0]     (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN
# US         (42.0, inf] 0              (-0.001, 7.0]     (-0.001, 1.0]            NaN
#                                                         (1.0, 7.0]               NaN
#                                                         (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]         0.015504
#                        1              (-0.001, 7.0]     (1.0, 7.0]               NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN
#
# run_date                                                                  2023-04-08  \
# par_region tenure      email_mismatch pw_tfa_days_group device_age_group
# AU         (42.0, inf] 0              (-0.001, 7.0]     (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN
# US         (42.0, inf] 0              (-0.001, 7.0]     (-0.001, 1.0]            NaN
#                                                         (1.0, 7.0]               NaN
#                                                         (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]         0.013089
#                        1              (-0.001, 7.0]     (1.0, 7.0]               NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]         0.038961
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN
#
# run_date                                                                  2023-04-09  \
# par_region tenure      email_mismatch pw_tfa_days_group device_age_group
# AU         (42.0, inf] 0              (-0.001, 7.0]     (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN
# US         (42.0, inf] 0              (-0.001, 7.0]     (-0.001, 1.0]            NaN
#                                                         (1.0, 7.0]               NaN
#                                                         (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                        1              (-0.001, 7.0]     (1.0, 7.0]               NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]         0.062857
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN
#
# run_date                                                                  2023-04-10  \
# par_region tenure      email_mismatch pw_tfa_days_group device_age_group
# AU         (42.0, inf] 0              (-0.001, 7.0]     (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN
# US         (42.0, inf] 0              (-0.001, 7.0]     (-0.001, 1.0]            NaN
#                                                         (1.0, 7.0]               NaN
#                                                         (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                        1              (-0.001, 7.0]     (1.0, 7.0]               NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]         0.088942
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN
#
# run_date                                                                  2023-04-11  \
# par_region tenure      email_mismatch pw_tfa_days_group device_age_group
# AU         (42.0, inf] 0              (-0.001, 7.0]     (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN
# US         (42.0, inf] 0              (-0.001, 7.0]     (-0.001, 1.0]            NaN
#                                                         (1.0, 7.0]               NaN
#                                                         (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                        1              (-0.001, 7.0]     (1.0, 7.0]               NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]         0.112676
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN
#
# run_date                                                                  2023-04-12  \
# par_region tenure      email_mismatch pw_tfa_days_group device_age_group
# AU         (42.0, inf] 0              (-0.001, 7.0]     (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN
# US         (42.0, inf] 0              (-0.001, 7.0]     (-0.001, 1.0]            NaN
#                                                         (1.0, 7.0]               NaN
#                                                         (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                        1              (-0.001, 7.0]     (1.0, 7.0]               NaN
#                                                         (7.0, 30.0]         0.049550
#                                       (14.0, 30.0]      (7.0, 30.0]         0.152466
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN
#
# run_date                                                                  2023-04-13
# par_region tenure      email_mismatch pw_tfa_days_group device_age_group
# AU         (42.0, inf] 0              (-0.001, 7.0]     (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN
# US         (42.0, inf] 0              (-0.001, 7.0]     (-0.001, 1.0]            NaN
#                                                         (1.0, 7.0]               NaN
#                                                         (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                                       (14.0, 30.0]      (7.0, 30.0]              NaN
#                                       (7.0, 14.0]       (30.0, 60.0]             NaN
#                                                         (7.0, 30.0]              NaN
#                        1              (-0.001, 7.0]     (1.0, 7.0]               NaN
#                                                         (7.0, 30.0]         0.056122
#                                       (14.0, 30.0]      (7.0, 30.0]         0.232323
#                                       (7.0, 14.0]       (7.0, 30.0]              NaN

# %%
report.shape
# Out:
# (15, 39)

# %%
bad_rate.shape
# Out:
# (200, 55)

# %%
def make_pretty(styler):
    styler.format('{:.0%}', na_rep='')
    #styler.format_index(lambda v: v.strftime("%A"))
    styler.background_gradient(cmap='Greens', low=0, high=0.5)#(axis=None, vmin=10, vmax=100,cmap='Greens')
    #styler.highlight_between(left=0, right=100, color='#b2fce4')#, props='color:black; background-color:#b2fce4;') 
    styler.set_table_styles([dict(selector='th', props='min-width: 5px;'),])
    return styler

# %%
report.fillna(0).iloc[:,20:].style.pipe(make_pretty)#.applymap('{:.2%}'.format)#.replace('nan%','') #.style.format(na_rep='')#.highlight_between(left=0, right=100)
# Out:
# <style type="text/css">
# #T_b80e8_ th {
#   min-width: 5px;
# }
# #T_b80e8_row0_col0, #T_b80e8_row0_col1, #T_b80e8_row0_col2, #T_b80e8_row0_col3, #T_b80e8_row0_col4, #T_b80e8_row0_col5, #T_b80e8_row0_col6, #T_b80e8_row0_col7, #T_b80e8_row0_col8, #T_b80e8_row0_col9, #T_b80e8_row0_col10, #T_b80e8_row0_col11, #T_b80e8_row0_col12, #T_b80e8_row0_col13, #T_b80e8_row0_col14, #T_b80e8_row0_col15, #T_b80e8_row0_col16, #T_b80e8_row0_col17, #T_b80e8_row0_col18, #T_b80e8_row1_col0, #T_b80e8_row1_col1, #T_b80e8_row1_col4, #T_b80e8_row1_col5, #T_b80e8_row1_col6, #T_b80e8_row1_col7, #T_b80e8_row1_col8, #T_b80e8_row1_col9, #T_b80e8_row1_col10, #T_b80e8_row1_col11, #T_b80e8_row1_col12, #T_b80e8_row1_col13, #T_b80e8_row1_col14, #T_b80e8_row1_col15, #T_b80e8_row1_col16, #T_b80e8_row1_col17, #T_b80e8_row1_col18, #T_b80e8_row2_col0, #T_b80e8_row2_col1, #T_b80e8_row2_col2, #T_b80e8_row2_col3, #T_b80e8_row2_col6, #T_b80e8_row2_col7, #T_b80e8_row2_col8, #T_b80e8_row2_col9, #T_b80e8_row2_col10, #T_b80e8_row2_col11, #T_b80e8_row2_col12, #T_b80e8_row2_col13, #T_b80e8_row2_col14, #T_b80e8_row2_col15, #T_b80e8_row2_col16, #T_b80e8_row2_col17, #T_b80e8_row2_col18, #T_b80e8_row3_col0, #T_b80e8_row3_col1, #T_b80e8_row3_col2, #T_b80e8_row3_col3, #T_b80e8_row3_col4, #T_b80e8_row3_col5, #T_b80e8_row3_col6, #T_b80e8_row3_col9, #T_b80e8_row3_col10, #T_b80e8_row3_col11, #T_b80e8_row3_col12, #T_b80e8_row3_col13, #T_b80e8_row3_col14, #T_b80e8_row3_col15, #T_b80e8_row3_col16, #T_b80e8_row3_col17, #T_b80e8_row3_col18, #T_b80e8_row4_col0, #T_b80e8_row4_col1, #T_b80e8_row4_col2, #T_b80e8_row4_col3, #T_b80e8_row4_col4, #T_b80e8_row4_col5, #T_b80e8_row4_col6, #T_b80e8_row4_col7, #T_b80e8_row4_col8, #T_b80e8_row4_col10, #T_b80e8_row4_col11, #T_b80e8_row4_col12, #T_b80e8_row4_col13, #T_b80e8_row4_col14, #T_b80e8_row4_col15, #T_b80e8_row4_col16, #T_b80e8_row4_col17, #T_b80e8_row4_col18, #T_b80e8_row5_col0, #T_b80e8_row5_col1, #T_b80e8_row5_col2, #T_b80e8_row5_col3, #T_b80e8_row5_col4, #T_b80e8_row5_col6, #T_b80e8_row5_col7, #T_b80e8_row5_col11, #T_b80e8_row5_col12, #T_b80e8_row5_col13, #T_b80e8_row5_col14, #T_b80e8_row5_col15, #T_b80e8_row5_col16, #T_b80e8_row5_col17, #T_b80e8_row5_col18, #T_b80e8_row6_col0, #T_b80e8_row6_col1, #T_b80e8_row6_col2, #T_b80e8_row6_col3, #T_b80e8_row6_col4, #T_b80e8_row6_col5, #T_b80e8_row6_col6, #T_b80e8_row6_col7, #T_b80e8_row6_col8, #T_b80e8_row6_col9, #T_b80e8_row6_col10, #T_b80e8_row6_col11, #T_b80e8_row6_col12, #T_b80e8_row6_col13, #T_b80e8_row6_col14, #T_b80e8_row6_col15, #T_b80e8_row6_col16, #T_b80e8_row6_col17, #T_b80e8_row6_col18, #T_b80e8_row7_col2, #T_b80e8_row7_col3, #T_b80e8_row7_col4, #T_b80e8_row7_col5, #T_b80e8_row7_col6, #T_b80e8_row7_col7, #T_b80e8_row7_col8, #T_b80e8_row7_col9, #T_b80e8_row7_col10, #T_b80e8_row7_col11, #T_b80e8_row7_col12, #T_b80e8_row7_col13, #T_b80e8_row7_col14, #T_b80e8_row7_col15, #T_b80e8_row7_col16, #T_b80e8_row7_col17, #T_b80e8_row7_col18, #T_b80e8_row8_col1, #T_b80e8_row8_col2, #T_b80e8_row8_col3, #T_b80e8_row8_col4, #T_b80e8_row8_col5, #T_b80e8_row8_col6, #T_b80e8_row8_col7, #T_b80e8_row8_col8, #T_b80e8_row8_col9, #T_b80e8_row8_col10, #T_b80e8_row8_col11, #T_b80e8_row8_col12, #T_b80e8_row8_col13, #T_b80e8_row8_col14, #T_b80e8_row8_col15, #T_b80e8_row8_col16, #T_b80e8_row8_col17, #T_b80e8_row8_col18, #T_b80e8_row9_col0, #T_b80e8_row9_col1, #T_b80e8_row9_col2, #T_b80e8_row9_col3, #T_b80e8_row9_col6, #T_b80e8_row9_col7, #T_b80e8_row9_col8, #T_b80e8_row9_col9, #T_b80e8_row9_col10, #T_b80e8_row9_col11, #T_b80e8_row9_col12, #T_b80e8_row9_col13, #T_b80e8_row9_col14, #T_b80e8_row9_col15, #T_b80e8_row9_col16, #T_b80e8_row9_col17, #T_b80e8_row9_col18, #T_b80e8_row10_col0, #T_b80e8_row10_col6, #T_b80e8_row10_col7, #T_b80e8_row10_col9, #T_b80e8_row10_col10, #T_b80e8_row10_col11, #T_b80e8_row10_col14, #T_b80e8_row10_col15, #T_b80e8_row10_col16, #T_b80e8_row10_col17, #T_b80e8_row10_col18, #T_b80e8_row11_col11, #T_b80e8_row11_col12, #T_b80e8_row11_col13, #T_b80e8_row11_col14, #T_b80e8_row11_col15, #T_b80e8_row11_col16, #T_b80e8_row11_col17, #T_b80e8_row11_col18, #T_b80e8_row12_co ...
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_b80e8_row1_col2, #T_b80e8_row3_col8 {
#   background-color: #f5fbf2;
#   color: #000000;
# }
# #T_b80e8_row1_col3, #T_b80e8_row8_col0 {
#   background-color: #f2faf0;
#   color: #000000;
# }
# #T_b80e8_row2_col4, #T_b80e8_row10_col5, #T_b80e8_row13_col2 {
#   background-color: #ecf8e8;
#   color: #000000;
# }
# #T_b80e8_row2_col5, #T_b80e8_row10_col2 {
#   background-color: #eff9ec;
#   color: #000000;
# }
# #T_b80e8_row3_col7 {
#   background-color: #f4fbf2;
#   color: #000000;
# }
# #T_b80e8_row4_col9, #T_b80e8_row7_col1 {
#   background-color: #f3faf0;
#   color: #000000;
# }
# #T_b80e8_row5_col5 {
#   background-color: #e4f5df;
#   color: #000000;
# }
# #T_b80e8_row5_col8 {
#   background-color: #edf8e9;
#   color: #000000;
# }
# #T_b80e8_row5_col9 {
#   background-color: #daf0d4;
#   color: #000000;
# }
# #T_b80e8_row5_col10 {
#   background-color: #ebf7e7;
#   color: #000000;
# }
# #T_b80e8_row7_col0, #T_b80e8_row10_col8 {
#   background-color: #f0f9ed;
#   color: #000000;
# }
# #T_b80e8_row9_col4 {
#   background-color: #d7efd1;
#   color: #000000;
# }
# #T_b80e8_row9_col5, #T_b80e8_row12_col1 {
#   background-color: #e7f6e2;
#   color: #000000;
# }
# #T_b80e8_row10_col1 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_b80e8_row10_col3 {
#   background-color: #def2d9;
#   color: #000000;
# }
# #T_b80e8_row10_col4 {
#   background-color: #a8dca2;
#   color: #000000;
# }
# #T_b80e8_row10_col12, #T_b80e8_row11_col0, #T_b80e8_row11_col1, #T_b80e8_row11_col2, #T_b80e8_row11_col3, #T_b80e8_row11_col5, #T_b80e8_row11_col6, #T_b80e8_row11_col7, #T_b80e8_row11_col8, #T_b80e8_row11_col9, #T_b80e8_row11_col10, #T_b80e8_row12_col11, #T_b80e8_row13_col13, #T_b80e8_row13_col14, #T_b80e8_row13_col15, #T_b80e8_row13_col16, #T_b80e8_row13_col17, #T_b80e8_row13_col18, #T_b80e8_row14_col4 {
#   background-color: #37a055;
#   color: #f1f1f1;
# }
# #T_b80e8_row10_col13 {
#   background-color: #cdecc7;
#   color: #000000;
# }
# #T_b80e8_row11_col4 {
#   background-color: #3aa357;
#   color: #f1f1f1;
# }
# #T_b80e8_row12_col0, #T_b80e8_row12_col17 {
#   background-color: #cfecc9;
#   color: #000000;
# }
# #T_b80e8_row12_col5 {
#   background-color: #40aa5d;
#   color: #f1f1f1;
# }
# #T_b80e8_row12_col6 {
#   background-color: #99d595;
#   color: #000000;
# }
# #T_b80e8_row12_col7, #T_b80e8_row14_col3 {
#   background-color: #80ca80;
#   color: #000000;
# }
# #T_b80e8_row12_col8 {
#   background-color: #d1edcb;
#   color: #000000;
# }
# #T_b80e8_row12_col18 {
#   background-color: #dcf2d7;
#   color: #000000;
# }
# #T_b80e8_row13_col10 {
#   background-color: #e1f3dc;
#   color: #000000;
# }
# #T_b80e8_row13_col11 {
#   background-color: #d5efcf;
#   color: #000000;
# }
# #T_b80e8_row14_col0 {
#   background-color: #ccebc6;
#   color: #000000;
# }
# #T_b80e8_row14_col1 {
#   background-color: #e0f3db;
#   color: #000000;
# }
# #T_b80e8_row14_col2 {
#   background-color: #c2e7bb;
#   color: #000000;
# }
# #T_b80e8_row14_col5 {
#   background-color: #81ca81;
#   color: #000000;
# }
# #T_b80e8_row14_col6 {
#   background-color: #76c578;
#   color: #000000;
# }
# #T_b80e8_row14_col7 {
#   background-color: #94d390;
#   color: #000000;
# }
# </style>
# <table id="T_b80e8_">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >run_date</th>
#       <th class="col_heading level0 col0" >2023-03-18</th>

# %%
#coverage
bad[(bad_rate>0.005) & ((bad_rate>3*bad_rate_rolling) & (bad>=3) | (bad>=5))].sum().sum()/bad.dropna(how='all').dropna(how='all',axis=1).sum().sum()
# Out:
# 0.6436170212765957

# %%
#coverage
bad[(bad_rate>0.005) & ((bad_rate>3*bad_rate_rolling) & (bad>=3) | (bad>=5))].sum().sum()
# Out:
# 907.5

# %%
bad.dropna(how='all').dropna(how='all',axis=1).sum().sum()
# Out:
# 1410.0
